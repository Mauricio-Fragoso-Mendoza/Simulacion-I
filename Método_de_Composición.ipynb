# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauricio-Fragoso-Mendoza/Simulacion-I/blob/main/M%C3%A9todo_de_Composici%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Para el triángulo cuyas áreas son: $A_1=\frac{b-a}{c-a}$ y $A_2=\frac{c-b}{c-a}$ se hará uso de las siguientes funciones:
# $$f_1(x) = \cases{0&si $x<a$,\cr \frac{2(x-a)}{(b-a)^2}&si $a \leq x \leq b$, \cr 0&si $x>b$}$$
# y
# $$f_2(x) = \cases{0&si $x<b$,\cr - \frac{2(x-c)}{(c-b)^2}&si $b \leq x \leq c$, \cr 0&si $x>c$}$$

# %% [markdown]
# Entonces: $F_1(X)=\frac{(x-a)^2}{(b-a)^2}$ y $F_2(x)=1-\frac{(x-c)^2}{(c-b)^2}$
#
# Usando la Transformada Inversa para la primera función se obtendrá R_1:
# $x=a+(b-a)\sqrt{R_1}$

# %%
def f1(n):
    l = []
    for i in range(n):
        u1 = r.random()
        if 0 <= u < 0.5:
            x = np.sqrt(2*u)
            l.append(x)
        else:
            x = 2-np.sqrt(2*(1-u))
            l.append(x)
    return l
