# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauricio-Fragoso-Mendoza/Simulacion-I/blob/main/Ejercicio%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Los coeficientes $p$ y $q$ de la ecuación cuadrática $$x^2+px+q=0$$ son tomadas aleatoriamente en el intervalo (0,2), ¿Cuál es la probabilidad de que la ecuación tenga raíces reales?

# %% [markdown]
# Resolviendo de forma analítica se aplicará la fórmula general:
# $$x=\frac{-p \pm \sqrt{p^2-4q}}{2}$$
#
# Para saber cómo se obtendrá la probabilidad de que la ecuación tenga raíces reales, se observará al factor discriminante: $p^2-4q$
#
# Sí $$

# %%
import as

# %%
return rd.uniform(0,2)

# %%
def raices_reales(n):
contador=0
for i in range(n):
p=aleatorio()
q=aleatorio()
if p**2-4*q < 0:
contador=contador
else:
contador=contador+1
