# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauricio-Fragoso-Mendoza/Simulacion-I/blob/main/Generador_Congruencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tabulate

# %%
def generador(a,b,m,x0):
    x1=(a*x0+b) %m
    return x1

# %%
def generador(a,b,m,x0):
    x1=(a*x0+b) %m
    return x1

n=20
a=4
b=7
m=9
x0=2

muestra=[]
datos=[]

for i in range(n):
   nuevo=generador(a,b,m,x0)
   muestra.append([i,x0,nuevo/64])
   datos.append(x0/64)
   x0=nuevo

encabezados=["i", "x_i", "X_{i_1}"]
print(tabulate.tabulate(muestra, headers=encabezados,tablefmt="psql",numalign="center"))
# Out:
# +-----+-------+-----------+
# |  i  |  x_i  |  X_{i_1}  |
# |-----+-------+-----------|
# |  0  |   2   |  0.09375  |
# |  1  |   6   |  0.0625   |
# |  2  |   4   | 0.078125  |
# |  3  |   5   |     0     |
# |  4  |   0   | 0.109375  |
# |  5  |   7   |   0.125   |
# |  6  |   8   | 0.046875  |
# |  7  |   3   | 0.015625  |
# |  8  |   1   |  0.03125  |
# |  9  |   2   |  0.09375  |
# | 10  |   6   |  0.0625   |
# | 11  |   4   | 0.078125  |
# | 12  |   5   |     0     |
# | 13  |   0   | 0.109375  |
# | 14  |   7   |   0.125   |
# | 15  |   8   | 0.046875  |
# | 16  |   3   | 0.015625  |
# | 17  |   1   |  0.03125  |
# | 18  |   2   |  0.09375  |
# | 19  |   6   |  0.0625   |
# +-----+-------+-----------+
