# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauricio-Fragoso-Mendoza/Simulacion-I/blob/main/Generador_Congruencial_(Ejercicios).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tabulate

# %%
a = 5
c = 1
m = 128
x0 = 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def generador(a,c,m,x0):
    x1=(a*x0+c) %m
    return x1

# %% [markdown]
# Ejercicio 1. Tomar $m = 2^7$ y elegir los parámetros adecuados para obtener una muestra de números aleatorios con ciclo de vida completos,
# a) Guardar los números en una lista y obtener su media
# b) Graficar el histograma de la muestra

# %% [markdown]
# Solución:
#
# a)Se generará la siguiente lista de números

# %%
generador(a,c,m,x0)
# Out:
# 6

# %%
L=[]
for i in range(m):
    nuevo = generador(a,c,m,x0)
    L.append([nuevo/m])

# %%
muestra=[]
datos=[]
for i in range(130):
    nuevo = generador(a,c,m,x0) # Update x0 for the next iteration
    muestra.append([i, x0, nuevo/m])
datos.append(nuevo/m)
x0 = nuevo

# %%
muestra
# Out:
# [[0, 56, 0.1953125],
#  [1, 56, 0.1953125],
#  [2, 56, 0.1953125],
#  [3, 56, 0.1953125],
#  [4, 56, 0.1953125],
#  [5, 56, 0.1953125],
#  [6, 56, 0.1953125],
#  [7, 56, 0.1953125],
#  [8, 56, 0.1953125],
#  [9, 56, 0.1953125],
#  [10, 56, 0.1953125],
#  [11, 56, 0.1953125],
#  [12, 56, 0.1953125],
#  [13, 56, 0.1953125],
#  [14, 56, 0.1953125],
#  [15, 56, 0.1953125],
#  [16, 56, 0.1953125],
#  [17, 56, 0.1953125],
#  [18, 56, 0.1953125],
#  [19, 56, 0.1953125],
#  [20, 56, 0.1953125],
#  [21, 56, 0.1953125],
#  [22, 56, 0.1953125],
#  [23, 56, 0.1953125],
#  [24, 56, 0.1953125],
#  [25, 56, 0.1953125],
#  [26, 56, 0.1953125],
#  [27, 56, 0.1953125],
#  [28, 56, 0.1953125],
#  [29, 56, 0.1953125],
#  [30, 56, 0.1953125],
#  [31, 56, 0.1953125],
#  [32, 56, 0.1953125],
#  [33, 56, 0.1953125],
#  [34, 56, 0.1953125],
#  [35, 56, 0.1953125],
#  [36, 56, 0.1953125],
#  [37, 56, 0.1953125],
#  [38, 56, 0.1953125],
#  [39, 56, 0.1953125],
#  [40, 56, 0.1953125],
#  [41, 56, 0.1953125],
# ...

# %%
L
# Out:
# [[0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
#  [0.1953125],
# ...

# %% [markdown]
# Por lo que la media es: $\mu = $
#
#
# b) El histograma queda como

# %%
d = datos

# %%
np.mean(d) #Calcula la media
# Out:
# np.float64(0.1953125)

# %%
1/2
# Out:
# 0.5

# %%
np.var(d)
# Out:
# np.float64(0.0)

# %%
1/12
# Out:
# 0.08333333333333333

# %%
plt.hist(d,bins=10)
plt.show()
